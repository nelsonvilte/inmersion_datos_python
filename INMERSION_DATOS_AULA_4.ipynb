# %% [markdown]
# <a href="https://colab.research.google.com/github/nelsonvilte/inmersion_datos_python/blob/aula-4/INMERSION_DATOS_AULA_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INMERSIÓN DATOS - CLASE 01 - TU PRIMER COLAB CON PYTHON Y PANDAS**
#
# Bienvenidos a nuestro primer encuentro de inmersion de datos.

# %%
#importo paquete de Drive que va ha permitir montar cuenta de Drive 

from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
#asignacion del dataset a la variable inmueble
inmuebles = pd.read_csv('/content/drive/MyDrive/BBDD Inmersion de datos - Alura/inmuebles_bogota.csv')
#muestra los primeros 5 elementos
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
#Devuelve cantidad de filas y columnas, sin contar el indice
inmuebles.shape
# Out:
# (9520, 8)

# %%
#Devuelve la descripcion de las columnas
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
#Creacion de un diccionario columnas cada componente con su key y su valor
columnas = {'Baños':'Banos','Área':'Area'}
#Asignando a las columnas los valores contenidos en el diccionario columnas
inmuebles = inmuebles.rename(columns = columnas)
#Mostrar una muestra que visualiza 10 filas
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 1727  Apartamento           Apartamento en venta en La Granja             2
# 3235  Apartamento             Apartamento en venta en Tintala             3
# 5086  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 8363  Apartamento             Apartamento en venta en Bochica             2
# 97    Apartamento  Apartamento en venta en Zona Noroccidental             3
# 2152  Apartamento            Apartamento en venta en Fontibón             3
# 9333  Apartamento             Apartamento en venta en Usaquén             2
# 4233         Casa                   Casa en venta en Engativa             2
# 4641         Casa             Casa en venta en Barrios Unidos             3
# 8535  Apartamento      Apartamento en venta en Barrios Unidos             2
#
#       Banos  Area              Barrio                                 UPZ  \
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
# Qué hay en el índice 300?
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
inmuebles['Valor'][300:305]
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %%
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Banos', 'Area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
#Calculo el area promedio de todos los inmuebles del dataset
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
#Cantidad de inmuebles en el barrio Chico Reservado
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebles_barrio= inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(15).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# **Desafío**
#
#
# *  Promedio de área de todos los inmuebles en los barrios en el dataset. El top 10.
#
#
# *   Consultar otros datos estadísticos, conteo, mediana, valores mínimo y máximo.

# %% [markdown]
# Agrupar los datos por barrio y calcular el promedio de área:

# %%
promedio_por_barrio = inmuebles.groupby('Barrio')['Area'].mean()
promedio_por_barrio
# Out:
# Barrio
# Alameda                97.000000
# Alhambra              190.411765
# Andes Norte           124.857143
# Antonio Nariño        163.062500
# Barrancas              70.200000
#                          ...
# Villa Maria           207.153846
# Villas De Granada      86.590909
# Villemar               76.888889
# Zona Franca            54.000000
# Zona Noroccidental    135.785633
# Name: Area, Length: 149, dtype: float64

# %% [markdown]
# Ordenar los resultados en orden descendente y seleccionar los primeros 10 barrios:

# %%
top_10 = promedio_por_barrio.sort_values(ascending=False).head(10)
print(top_10)
# Out:
# Barrio
# Modelia                  4316.750000
# Libertador                642.000000
# Bosa Piamonte             400.000000
# La Soledad                378.625000
# Restrepo                  336.500000
# Santa Librada             328.000000
# Las Ferias                320.000000
# Santa Ana                 309.375000
# Veraguas                  302.666667
# Bellavista Occidental     286.200000
# Name: Area, dtype: float64

# %%
top_10.head(15).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %%
import matplotlib.pyplot as plt

# %%
# Obtener los datos correspondientes al top 10
datos_top_10 = promedio_por_barrio[top_10.index]

# %%
# Crear la gráfica
plt.figure(figsize=(10,6))
plt.bar(datos_top_10.index, datos_top_10.values)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# Para personalizar el gráfico, se pueden modificar los parámetros de la función ax.bar() y las etiquetas de los ejes x e y. En este ejemplo, se establece un tamaño de figura de 10x6, se añade un título y etiquetas a los ejes, se rota las etiquetas de los ejes x en 45 grados y se muestra el gráfico utilizando la función plt.show().

# %%
# Generar gráfico de barras
fig, ax = plt.subplots(figsize=(10,6))
ax.bar(top_10.index, top_10.values)
ax.set_title('Promedio de área por barrio')
ax.set_xlabel('Barrio')
ax.set_ylabel('Promedio de área')
plt.xticks(rotation=45)
# Mostrar la gráfica
plt.show()

# %%
mediana = inmuebles.groupby('Barrio')['Area'].median()
print(mediana)
# Out:
# Barrio
# Alameda                97.0
# Alhambra              164.0
# Andes Norte           108.0
# Antonio Nariño         72.0
# Barrancas              75.0
#                       ...
# Villa Maria           222.0
# Villas De Granada      64.0
# Villemar               59.0
# Zona Franca            54.0
# Zona Noroccidental     78.0
# Name: Area, Length: 149, dtype: float64

# %%
# Calcular la mediana de área por barrio
mediana = mediana.sort_values(ascending=False)
print(mediana)
# Out:
# Barrio
# Libertador           642.0
# Bosa Piamonte        400.0
# Restrepo             365.0
# Santa Librada        328.0
# Las Ferias           320.0
#                      ...
# Bochica               39.0
# La Macarena           37.0
# San Diego             36.5
# Chapinero Central     36.0
# Prado Veraniego       25.0
# Name: Area, Length: 149, dtype: float64

# %%
# Ordenar los 15 primeros resultados en orden ascendente por mediana
mediana_por_barrio = mediana.head(15).sort_values(ascending=True)
# Generar gráfico de barras
fig, ax = plt.subplots(figsize=(20,6))
ax.bar(mediana_por_barrio.index, mediana_por_barrio.values)
ax.set_title('Mediana de área por barrio')
ax.set_xlabel('Barrio')
ax.set_ylabel('Mediana de área')
plt.xticks(rotation=45)
plt.show()

# %%
# Obtener el valor mínimo y máximo del área
minimo = inmuebles['Area'].min()
maximo = inmuebles['Area'].max()

# Imprimir los valores mínimo y máximo del área
print("El valor mínimo del área es:", minimo)
print("El valor máximo del área es:", maximo)
# Out:
# El valor mínimo del área es: 2
# El valor máximo del área es: 166243

# %%
# Encontrar el índice del valor mínimo y máximo del área
indice_min = inmuebles['Area'].idxmin()
indice_max = inmuebles['Area'].idxmax()

# Obtener el barrio correspondiente al valor mínimo y máximo del área
barrio_min = inmuebles.loc[indice_min, 'Barrio']
barrio_max = inmuebles.loc[indice_max, 'Barrio']

# Imprimir los barrios correspondientes al valor mínimo y máximo del área
print("El valor mínimo: ",minimo," del área corresponde al barrio:", barrio_min)
print("El valor máximo: ",maximo," del área corresponde al barrio:", barrio_max)
# Out:
# El valor mínimo:  2  del área corresponde al barrio: San Cristobal
# El valor máximo:  166243  del área corresponde al barrio: Modelia

# %% [markdown]
# # **INMERSIÓN DATOS - CLASE 02 - TRATAMIENTO DE DATOS Y PRIMEROS GRÁFICOS**
#
# Segunda clase de la Inmersión Datos con Python.
#
# En esta aula avanzaremos con nuestro análisis y vamos a iniciar el tratamiento de los datos para trabajar con las primeras visualizaciones con Seaborn. Tendremos casi de todo: Estadística, visualización de datos e incluso tratamiento de strings.

# %%
#Tomamos una muestra de 5 filas
inmuebles.sample(5)
# Out:
#              Tipo                          Descripcion  Habitaciones  Banos  \
# 4711         Casa      Casa en venta en Barrios Unidos             4      4
# 7693  Apartamento     Apartamento en venta en Engativa             4      3
# 1964  Apartamento      Apartamento en venta en Usaquén             3      3
# 4463         Casa             Casa en venta en Kennedy             3      2
# 8788  Apartamento  Apartamento en venta en Bella Suiza             2      2
#
#       Area          Barrio                                    UPZ  \
# 4711   144  Barrios Unidos                              Los Andes
# 7693   270        Engativa                               Engativá
# 1964    54         Usaquén                                Usaquén
# 4463    61         Kennedy                        Kennedy Central
# 8788    78     Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#               Valor
# 4711  $ 500.000.000
# 7693  $ 670.000.000
# 1964  $ 220.000.000
# 4463  $ 155.000.000
# ...

# %%
#Ver el tipo de datos que ya en cada columna
inmuebles.info()
#Existen 3 columnas de tipo entero y 5 columnas de tipo objeto (string)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
#Determinar el valor de Valor[0] que al parecer es un numero entero
inmuebles.Valor[0]
# Out:
# '$ 360.000.000'

# %%
#Determinar el tipo de dato de Valor[0] que al parecer es entero

type(inmuebles.Valor[0])
# Out:
# str

# %%
#Intentando sumar Valor[0] y Valor[1] como si fuesen numeros
inmuebles.Valor[0] + inmuebles.Valor[1]
# Out:
# '$ 360.000.000$ 670.000.000'

# %%
inmuebles.Valor[0] + inmuebles.Valor[1] + inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %% [markdown]
# **Aplicando funciones de String**

# %%
#Split separa una cadena de texto en funcion de algun parametro dado, por default toma el espacio en blanco.Devuelve una lista
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
type(inmuebles.Valor[0].split())
# Out:
# list

# %%
#Aplicando a toda la columna, convirtiendo primero todo en str para poderle aplicar split()
inmuebles.Valor.str.split()
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %%
type(inmuebles.Valor.str.split())
# Out:
# pandas.core.series.Series

# %%
#Convertir en formato de Dataframe
type(inmuebles.Valor.str.split(expand=True))
# Out:
# pandas.core.frame.DataFrame

# %%
inmuebles.Valor.str.split(expand=True)
# Out:
#       0              1
# 0     $    360.000.000
# 1     $    670.000.000
# 2     $  1.120.000.000
# 3     $    890.000.000
# 4     $    970.000.000
# ...  ..            ...
# 9515  $    290.000.000
# 9516  $    670.000.000
# 9517  $    900.000.000
# 9518  $    335.000.000
# 9519  $    144.990.000
#
# [9520 rows x 2 columns]

# %%
valor = inmuebles.Valor.str.split(expand=True)
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]

inmuebles.sample(3)
# Out:
#              Tipo                                Descripcion  Habitaciones  \
# 511   Apartamento      Apartamento en venta en Santa Barbara             3
# 5836  Apartamento  Apartamento en venta en Villas De Granada             3
# 4704  Apartamento               Apartamento en venta en Suba             3
#
#       Banos  Area             Barrio                                    UPZ  \
# 511       2    75      Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 5836      2    64  Villas De Granada                           Garcés Navas
# 4704      4   235               Suba                                   Suba
#
#                 Valor Moneda         Precio
# 511     $ 314.000.000      $    314.000.000
# 5836    $ 190.000.000      $    190.000.000
# 4704  $ 1.850.000.000      $  1.850.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
#La columna precio todavia tiene formato de string
inmuebles['Precio'].sum()
# Out:
# '360.000.000670.000.0001.120.000.000890.000.000970.000.000510.000.000500.000.0002.350.000.000850.000.000642.000.000652.000.000168.000.000205.000.000300.000.000680.000.0002.519.000.000420.000.000620.000.000239.000.0001.600.000.000420.000.000625.000.0002.799.000.0001.450.000.0002.000.000.000670.000.0001.800.000.000469.000.000580.000.000445.000.000261.500.000278.000.000258.000.000520.000.000200.000.000129.000.000350.000.000290.500.000750.000.000495.000.000285.000.000900.000.0001.800.000.000990.000.000418.000.000349.000.000565.000.000370.000.000259.000.000310.000.000354.000.000372.000.000500.000.000420.000.0001.050.000.000185.000.000349.000.000515.000.000287.000.000265.000.000500.000.000261.500.000300.000.000278.000.000258.000.000520.000.000350.000.000290.500.000129.000.000200.000.000750.000.000418.000.000495.000.000349.000.000310.000.000565.000.000370.000.000259.000.000354.000.000285.000.000420.000.000372.000.000500.000.000185.000.0001.050.000.000349.000.0001.800.000.000900.000.000990.0
# ...

# %%
#Reemplazar "." por ningun caracter para convertir entero los valores de la columna Precio
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','', regex=True)

# %%
#Confirmamos la eliminacion del punto en los valores de la columna Precio
inmuebles[['Precio','Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
#Determinamos que la columna Precio continua manteniendo el tipo string
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio_Millon']= inmuebles.Precio.astype('float')/1000000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.sample(3)
# Out:
#              Tipo                       Descripcion  Habitaciones  Banos  \
# 3232  Apartamento   Apartamento en venta en Usaquén             3      3
# 7961         Casa             Casa en venta en Suba            16      7
# 1494  Apartamento  Apartamento en venta en Santa Fe             1      1
#
#       Area    Barrio                                     UPZ            Valor  \
# 3232   150   Usaquén                                 Usaquén    $ 930.000.000
# 7961   392      Suba                                    Suba  $ 1.300.000.000
# 1494    52  Santa Fe  SANTA FE: Las Nieves + Sagrado Corazón    $ 420.000.000
#
#      Moneda      Precio  Precio_Millon
# 3232      $   930000000          930.0
# 7961      $  1300000000         1300.0
# 1494      $   420000000          420.0

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option('display.precision',2)
pd.set_option('display.float_format', lambda x:'%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %% [markdown]
# Se determinan los errores Habitaciones:110 y Area: 2
# Se realizan las consultas correspondientes.

# %%
#Metodo "loc" localiza los atributos que cumplan con cierta condición
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %%
inmuebles['Precio_Millon'].plot.hist(bins=150)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Bibliotecas Gráficas: Matplotlib y Seaborn**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#prepación del lienzo donde se va ha realizar la gráfica
plt.figure(figsize=(10,8))
grafica = sns.histplot(data = inmuebles, x='Precio_Millon')
grafica.set_title('Distribución de valores de los inmuebles en Bogotá')
plt.xlim((50, 2000))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#prepación del lienzo donde se va ha realizar la gráfica
plt.figure(figsize=(10,6))
grafica = sns.histplot(data = inmuebles, x='Precio_Millon')
grafica.set_title('Distribución de valores de los inmuebles en Bogotá')
plt.xlim((50, 1000))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#prepación del lienzo donde se va ha realizar la gráfica
plt.figure(figsize=(10,6))
grafica = sns.histplot(data = inmuebles, x='Precio_Millon', kde= True)
grafica.set_title('Distribución de valores de los inmuebles en Bogotá')
plt.xlim((50, 1000))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#prepación del lienzo donde se va ha realizar la gráfica, mostrando los tipos y exportar en formato png
plt.figure(figsize=(10,6))
grafica = sns.histplot(data = inmuebles, x='Precio_Millon', kde= True, hue='Tipo')
grafica.set_title('Distribución de valores de los inmuebles en Bogotá')
plt.xlim((50, 1000))
plt.savefig('/content/drive/MyDrive/Inmersion_Datos/valor_inmuebles.png',format='png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#prepación del lienzo donde se va ha realizar la gráfica mas acotada y exportar en formato png
plt.figure(figsize=(10,6))
grafica = sns.histplot(data = inmuebles, x='Precio_Millon', kde= True, hue='Tipo')
grafica.set_title('Distribución de valores de los inmuebles en Bogotá')
plt.xlim((50, 1000))
plt.ylim((0, 20))
plt.savefig('/content/drive/MyDrive/Inmersion_Datos/valor_inmuebles_limitado.png',format='png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ***Desafíos de esta aula***
#
# 1. Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles
# (Refinar el gráfico: Títulos, aumentar el tamaño de labels, colores, conclusión de la información);
#
# 2. Precio del m2 por barrio y hacer el gráfico más adecuado para esta nueva variable.

# %%
#Tomando como referencia el precio de todo el dataset y dividirlo por el area de todo el dataset
#Crear nueva columna  'Valor_m2_Millon' donde cada fila es igual a la division entre el precio y el area de cada inmueble
inmuebles['Valor_m2_Millon'] = inmuebles['Precio_Millon']/inmuebles['Area']
#Observamos los 3 primeros registros
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millon
# 0    $ 360.000.000      $   360000000         360.00             5.14
# 1    $ 670.000.000      $   670000000         670.00             3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00             7.78

# %% [markdown]
# Mostrar la sumatoria del precio de todos los inmuebles de cada barrio dividido por la sumatoria de todas las areas de cada barrio

# %%
#Mostrar el promedio de cada columna numerica agrupados por barrio
inmuebles.groupby('Barrio').mean()
# Out:
#                     Habitaciones  Banos   Area  Precio_Millon  Valor_m2_Millon
# Barrio
# Alameda                     3.00   2.00  97.00         580.00             5.98
# Alhambra                    3.00   2.94 190.41         752.35             4.33
# Andes Norte                 3.00   2.86 124.86         709.57             6.05
# Antonio Nariño              4.31   2.50 163.06         459.22             3.53
# Barrancas                   2.87   2.13  70.20         314.13             4.42
# ...                          ...    ...    ...            ...              ...
# Villa Maria                 4.69   3.69 207.15         402.85             2.04
# Villas De Granada           3.45   2.32  86.59         282.30             3.17
# Villemar                    2.94   2.06  76.89         303.83             3.99
# Zona Franca                 2.00   1.00  54.00         160.00             2.96
# Zona Noroccidental          3.17   2.51 135.79         620.81             4.62
#
# ...

# %%
#Sumando todos los datos numericos de cada barrio
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon
# Barrio
# Alameda                        5.98
# Alhambra                      73.56
# Andes Norte                   42.35
# Antonio Nariño               169.47
# ...

# %%
#Determina el promedio de metro cuadrado por barrrio con respecto a cada barrio
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_Millon']/datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon  Valor_m2_Barrio
# Barrio
# Alameda                        5.98             5.98
# Alhambra                      73.56             3.95
# ...

# %%
#Asignar el valor de 'Valor_m2_Barrio' de 'datos_barrio' y asingnarlo a 'Valor_m2_Barrio' de 'inmuebles'

# %%
#Crear diccionario con los valores de 'Valor_m2_Barrio' en 'datos_barrio'
m2_barrio = dict(datos_barrio['Valor_m2_Barrio'])

# %%
#Creación de nueva columna 'Valor_m2_Barrio' con los nombres de cada barrio
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']
#Sustitución del nuevo valor del m2 por barrio
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio)
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millon  \
# 0    $ 360.000.000      $   360000000         360.00             5.14
# 1    $ 670.000.000      $   670000000         670.00             3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00             7.78
#
#    Valor_m2_Barrio
# 0             4.57
# 1             3.40
# 2             8.10

# %%
#Los 10 primeros barrios que contienen mas inmuebles a la venta
inmuebles['Barrio'].value_counts()[:10].index
# Out:
# Index(['Usaquén', 'Zona Noroccidental', 'Bosa', 'Kennedy', 'Cedritos',
#        'Barrios Unidos', 'Engativa', 'Suba', 'Santa Barbara', 'Chapinero'],
#       dtype='object')

# %%
top_barrios=inmuebles['Barrio'].value_counts()[:10].index

# %%
#Mostrar que 'Barrio' es el indidce del dataset 'datos_barrio'
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon  Valor_m2_Barrio
# Barrio
# Alameda                        5.98             5.98
# Alhambra                      73.56             3.95
# ...

# %%
#Convertir el indice 'Barrio' en columna del dataset
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_Barrio
# 0               5.98             5.98
# 1              73.56             3.95
# ...

# %%
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_Barrio
# 5            2070.61             2.96
# 10           1654.36             2.68
# 22           2853.23             5.03
# 24           2466.03             4.58
# ...

# %%
#Configurando lienzo de la grafica
plt.figure(figsize=(10,8))
ax = sns.barplot(x= 'Barrio',y='Valor_m2_Barrio', data = datos_barrio.query('Barrio in @top_barrios'))

# %%
#Configurando lienzo de la grafica
plt.figure(figsize=(10,8))
ax = sns.barplot(x= 'Barrio',y='Valor_m2_Barrio', data = datos_barrio.query('Barrio in @top_barrios'))
#Configurando la visualizacion de labels
ax.tick_params(axis='x', rotation=60)

# %%
#Configurando lienzo de la grafica con boxplot
plt.figure(figsize=(10,8))
ax = sns.boxplot(x= 'Barrio',y='Valor_m2_Millon', data = inmuebles.query('Barrio in @top_barrios'))
#Configurando la visualizacion de labels
ax.tick_params(axis='x', rotation=60)
plt.show()

# %%
#Configurando lienzo de la grafica
plt.figure(figsize=(10,8))
ax = sns.boxplot(x= 'Barrio',y='Valor_m2_Millon', data = inmuebles.query('Barrio in @top_barrios & Valor_m2_Millon < 15'))
#Configurando la visualizacion de labels
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
#Configurando lienzo de la grafica
plt.figure(figsize=(10,8))
ax = sns.boxplot(x= 'Barrio',y='Area', data = inmuebles.query('Barrio in @top_barrios & Area < 500'))
#Configurando la visualizacion de labels
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
#Configurando lienzo de la grafica
plt.figure(figsize=(10,8))
ax = sns.boxplot(x= 'Barrio',y='Precio_Millon', data = inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
#Configurando la visualizacion de labels
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# # **INMERSIÓN DATOSCLASE 03 - PROFUNDIZANDO EL ANÁLISIS EXPLORATORIO**
#
# Vamos a traer datos estadísticos de la ciudad de Bogotá, directamente del DANE (Departamento Administrativo Nacional de Estadística)y vamos a ver como estos datos nos ayudarían en inclusión de nuevas variables para el cálculo del precio de los inmuebles en la ciudad de **Bogotá**.
#
# Encuesta Multiproposito de Bogotá para obtener información socio-económica y de entorno urbano de los habitantes de Bogotá para la formulación, seguimiento y evaluación de las políticas distritales.
#
# https://microdatos.dane.gov.co/index.php/catalog/743

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/BBDD Inmersion de datos - Alura/Aular 3 - DANE/Identificación (Capítulo A).csv', sep=';',encoding='latin-1')
datos_raw
# Out:
#         DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0       3004346.00    11  11001      1           3.00         Santa Fe
# 1       3004347.00    11  11001      1          14.00     Los Mártires
# 2       3004348.00    11  11001      1           3.00         Santa Fe
# 3       3004349.00    11  11001      1           1.00          Usaquén
# 4       3004350.00    11  11001      1           1.00          Usaquén
# ...            ...   ...    ...    ...            ...              ...
# 106462  3004341.00    11  11001      1           3.00         Santa Fe
# 106463  3004342.00    11  11001      1           3.00         Santa Fe
# 106464  3004343.00    11  11001      1          14.00     Los Mártires
# 106465  3004344.00    11  11001      1           3.00         Santa Fe
# 106466  3004345.00    11  11001      1           3.00         Santa Fe
#
#         COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# ...

# %%
#Muestra (filas, columnas) 
datos_raw.shape
# Out:
# (106467, 11)

# %%
#Localizar unicamente los datos referentes al distrito de Bogotá
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.shape
# Out:
# (86504, 11)

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/BBDD Inmersion de datos - Alura/Aular 3 - DANE/Datos de la vivenda y su entorno (Capítulo B).csv',sep=';',encoding='latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/BBDD Inmersion de datos - Alura/Aular 3 - DANE/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/BBDD Inmersion de datos - Alura/Aular 3 - DANE/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/BBDD Inmersion de datos - Alura/Aular 3 - DANE/Educación (Capítulo H).csv',sep=';',encoding='latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/BBDD Inmersion de datos - Alura/Aular 3 - DANE/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv',sep=';',encoding='latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/BBDD Inmersion de datos - Alura/Aular 3 - DANE/Fuerza de trabajo (Capítulo K).csv',sep=';',encoding='latin-1')
# Out:
# <ipython-input-93-a60f1ce4668e>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/BBDD Inmersion de datos - Alura/Aular 3 - DANE/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
# <ipython-input-93-a60f1ce4668e>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/BBDD Inmersion de datos - Alura/Aular 3 - DANE/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
# <ipython-input-93-a60f1ce4668e>:4: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/BBDD Inmersion de datos - Alura/Aular 3 - DANE/Educación (Capítulo H).csv',sep=';',encoding='latin-1')
# ...

# %%
datos_dane = pd.merge(datos_raw,datos_b,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane,datos_c,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# <ipython-input-96-50416a30d2ed>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %% [markdown]
# **Desafíos de esta aula**
#
# *   Dar un vistazo a la base de datos del DANE, comprender conceptualmente estas variables para entender mejor el contexto de esta base de datos;
# *   Organizar tu notebook para que tu proyecto quede mejor presentado.

# %% [markdown]
# # **INMERSIÓN DATOS - CLASE 04 - CRUZANDO BASES Y MACHINE LEARNING**

# %%
datos_dane = pd.read_csv('/content/drive/MyDrive/BBDD Inmersion de datos - Alura/Clase 4 - Dane/datos_dane.csv')
#Cantidad de filas y columnas
datos_dane.shape
# Out:
# (9857, 55)

# %%
#Información de cada columna del dataset
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DIRECTORIO        9857 non-null   float64
#  1   NOMBRE_LOCALIDAD  9857 non-null   object
#  2   NOMBRE_ESTRATO    9857 non-null   object
#  3   NVCBP4            9857 non-null   int64
#  4   NVCBP14A          9857 non-null   int64
#  5   NVCBP14D          9857 non-null   int64
#  6   NVCBP14E          9857 non-null   int64
#  7   NVCBP14G          9857 non-null   int64
#  8   NVCBP15A          9857 non-null   int64
#  9   NVCBP15C          9857 non-null   int64
#  10  NVCBP15F          9857 non-null   int64
#  11  NVCBP15G          9857 non-null   int64
#  12  NVCBP16A3         9857 non-null   int64
#  13  NVCBP16A4         9857 non-null   int64
#  14  NPCKP17           9857 non-null   float64
#  15  NPCKP18           9857 non-null   float64
# ...

# %%
#Renombrar el nombre de cada columna del dataset
dic_dane = {
       'NVCBP4':'CONJUNTO_CERRADO',
       'NVCBP14A':'FABRICAS_CERCA', 'NVCBP14D':'TERMINALES_BUS', 'NVCBP14E':'BARES_DISCO', 
       'NVCBP14G':'OSCURO_PELIGROSO', 'NVCBP15A':'RUIDO', 'NVCBP15C':'INSEGURIDAD',
       'NVCBP15F':'BASURA_INADECUADA', 'NVCBP15G':'INVASION','NVCBP16A3':'MOV_ADULTOS_MAYORES', 
       'NVCBP16A4':'MOV_NINOS_BEBES',
       'NPCKP17':'OCUPACION','NPCKP18':'CONTRATO','NPCKP23':'SALARIO_MES', 
       'NPCKP44A':'DONDE_TRABAJA', 'NPCKPN62A':'DECLARACION_RENTA', 
       'NPCKPN62B':'VALOR_DECLARACION', 'NPCKP64A':'PERDIDA_TRABAJO_C19', 
       'NPCKP64E':'PERDIDA_INGRESOS_C19',
       'NHCCP3':'TIENE_ESCRITURA', 'NHCCP6':'ANO_COMPRA', 'NHCCP7':'VALOR_COMPRA', 'NHCCP8_1':'HIPOTECA_CRED_BANCO',
       'NHCCP8_2':'OTRO_CRED_BANCO', 'NHCCP8_3':'CRED_FNA', 'NHCCP8_6':'PRESTAMOS_AMIGOS',
       'NHCCP8_7':'CESANTIAS', 'NHCCP8_8':'AHORROS', 'NHCCP8_9':'SUBSIDIOS',
       'NHCCP9':'CUANTO_PAGARIA_MENSUAL', 'NHCCP11':'PLANES_ADQUIRIR_VIVIENDA', 
       'NHCCP11A':'MOTIVO_COMPRA', 'NHCCP12':'RAZON_NO_ADQ_VIV', 'NHCCP41':'TIENE_CARRO','NHCCP41A':'CUANTOS_CARROS',
       'NHCCP47A':'TIENE_PERROS', 'NHCCP47B':'TIENE_GATOS', 'NHCLP2A':'VICTIMA_ATRACO', 'NHCLP2B':'VICTIMA_HOMICIDIO', 
       'NHCLP2C':'VICTIMA_PERSECUSION',
       'NHCLP2E':'VICTIMA_ACOSO', 'NHCLP4':'COMO_VIVE_ECON', 'NHCLP5':'COMO_NIVEL_VIDA', 
       'NHCLP8AB':'REACCION_OPORTUNA_POLICIA', 'NHCLP8AE':'COMO_TRANSPORTE_URBANO', 'NHCLP10':'SON_INGRESOS_SUFICIENTES',
       'NHCLP11':'SE_CONSIDERA_POBRE', 'NHCLP29_1A':'MED_C19_TRABAJO', 
       'NHCLP29_1C':'MED_C19_CAMBIO_VIVIENDA', 'NHCLP29_1E':'MED_C19_ENDEUDAMIENTO', 
       'NHCLP29_1F':'MED_C19_VENTA_BIENES','NPCHP4':'NIVEL_EDUCATIVO'
       }

datos_dane = datos_dane.rename(columns=dic_dane)
datos_dane.columns
# Out:
# Index(['DIRECTORIO', 'NOMBRE_LOCALIDAD', 'NOMBRE_ESTRATO', 'CONJUNTO_CERRADO',
#        'FABRICAS_CERCA', 'TERMINALES_BUS', 'BARES_DISCO', 'OSCURO_PELIGROSO',
#        'RUIDO', 'INSEGURIDAD', 'BASURA_INADECUADA', 'INVASION',
#        'MOV_ADULTOS_MAYORES', 'MOV_NINOS_BEBES', 'OCUPACION', 'CONTRATO',
#        'SALARIO_MES', 'DONDE_TRABAJA', 'DECLARACION_RENTA',
#        'VALOR_DECLARACION', 'PERDIDA_TRABAJO_C19', 'PERDIDA_INGRESOS_C19',
#        'TIENE_ESCRITURA', 'ANO_COMPRA', 'VALOR_COMPRA', 'HIPOTECA_CRED_BANCO',
#        'OTRO_CRED_BANCO', 'CRED_FNA', 'PRESTAMOS_AMIGOS', 'CESANTIAS',
#        'AHORROS', 'SUBSIDIOS', 'CUANTO_PAGARIA_MENSUAL',
#        'PLANES_ADQUIRIR_VIVIENDA', 'MOTIVO_COMPRA', 'RAZON_NO_ADQ_VIV',
#        'TIENE_CARRO', 'CUANTOS_CARROS', 'TIENE_PERROS', 'TIENE_GATOS',
#        'VICTIMA_ATRACO', 'VICTIMA_HOMICIDIO', 'VICTIMA_PERSECUSION',
#        'VICTIMA_ACOSO', 'COMO_VIVE_ECON', 'COMO_NIVEL_VIDA',
#        'REACCION_OPORTUNA_POLICIA', 'COMO_TRANSPORTE_URBANO',
# ...

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DIRECTORIO                 9857 non-null   float64
#  1   NOMBRE_LOCALIDAD           9857 non-null   object
#  2   NOMBRE_ESTRATO             9857 non-null   object
#  3   CONJUNTO_CERRADO           9857 non-null   int64
#  4   FABRICAS_CERCA             9857 non-null   int64
#  5   TERMINALES_BUS             9857 non-null   int64
#  6   BARES_DISCO                9857 non-null   int64
#  7   OSCURO_PELIGROSO           9857 non-null   int64
#  8   RUIDO                      9857 non-null   int64
#  9   INSEGURIDAD                9857 non-null   int64
#  10  BASURA_INADECUADA          9857 non-null   int64
#  11  INVASION                   9857 non-null   int64
#  12  MOV_ADULTOS_MAYORES        9857 non-null   int64
# ...

# %%
datos_dane.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean().head()
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   1.89
# Américas                                                      1.38
# Apogeo                                                        1.65
# Arborizadora                                                  1.43
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              1.37
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# 20 de Julio                                              1.19            1.85
# Américas                                                 1.25            1.98
# Apogeo                                                   1.30            1.75
# Arborizadora                                             1.30            1.95
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre         1.33            1.99
#
# ...

# %%
datos=datos_dane[['NOMBRE_ESTRATO','CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].replace(2,0)
datos
# Out:
#                                      NOMBRE_ESTRATO  CONJUNTO_CERRADO  \
# 0     USAQUÉN: Paseo de Los Libertadores + La Uribe                 1
# 1                                           Usaquén                 1
# 2                CHAPINERO: Pardo Rubio + Chapinero                 0
# 3                                        Los Cedros                 1
# 4                         Ciudad Salitre Occidental                 1
# ...                                             ...               ...
# 9852         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9853         SANTA FE: Las Nieves + Sagrado Corazón                 0
# 9854         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9855         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9856                                   Santa Isabel                 0
#
#       INSEGURIDAD  TERMINALES_BUS  BARES_DISCO  RUIDO  OSCURO_PELIGROSO  \
# ...

# %%
datos.loc[datos.NOMBRE_ESTRATO == '20 de Julio']
# Out:
#      NOMBRE_ESTRATO  CONJUNTO_CERRADO  INSEGURIDAD  TERMINALES_BUS  \
# 513     20 de Julio                 0            0               0
# 706     20 de Julio                 0            1               0
# 707     20 de Julio                 0            1               0
# 708     20 de Julio                 0            1               0
# 709     20 de Julio                 0            1               0
# ...             ...               ...          ...             ...
# 8372    20 de Julio                 0            1               0
# 8751    20 de Julio                 0            0               0
# 8752    20 de Julio                 0            1               0
# 8783    20 de Julio                 0            1               1
# 9287    20 de Julio                 0            1               0
#
#       BARES_DISCO  RUIDO  OSCURO_PELIGROSO  SALARIO_MES  TIENE_ESCRITURA  \
# 513             0      1                 0        98.00             1.00
# ...

# %%
datos_tratados=datos.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean()
datos_tratados
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   0.11
# Américas                                                      0.62
# Apogeo                                                        0.35
# Arborizadora                                                  0.57
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              0.63
# ...                                                            ...
# Usaquén                                                       0.90
# Venecia                                                       0.47
# Verbenal                                                      0.77
# Zona Franca                                                   0.94
# Álamos                                                        0.65
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# ...

# %%
pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
datos_ml = pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9520 entries, 0 to 9519
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9520 non-null   object
#  1   Descripcion               9520 non-null   object
#  2   Habitaciones              9520 non-null   int64
#  3   Banos                     9520 non-null   int64
#  4   Area                      9520 non-null   int64
#  5   Barrio                    9520 non-null   object
#  6   UPZ                       9478 non-null   object
#  7   Valor                     9520 non-null   object
#  8   Moneda                    9520 non-null   object
#  9   Precio                    9520 non-null   object
#  10  Precio_Millon             9520 non-null   float64
#  11  Valor_m2_Millon           9520 non-null   float64
#  12  Valor_m2_Barrio           9520 non-null   float64
# ...

# %%
upz = pd.read_csv('/content/drive/MyDrive/BBDD Inmersion de datos - Alura/Clase 4 - Dane/cod_upz.csv')
datos_ml = pd.merge(datos_ml,upz,left_on='UPZ',right_on='NOMBRE_ESTRATO', how='inner')
datos_ml.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                      Casa en venta en Marly             3
# 2         Casa         Casa en venta en Zona Noroccidental             3
# 3  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4         Casa         Casa en venta en Zona Noroccidental             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   147               Marly  CHAPINERO: Pardo Rubio + Chapinero
# 2      4   300  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 3      1    45  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 4      6   380  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
#
#              Valor Moneda      Precio  ...  BARES_DISCO  RUIDO  \
# ...

# %%
datos_ml.shape
# Out:
# (9318, 26)

# %%
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9318 entries, 0 to 9317
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9318 non-null   object
#  1   Descripcion               9318 non-null   object
#  2   Habitaciones              9318 non-null   int64
#  3   Banos                     9318 non-null   int64
#  4   Area                      9318 non-null   int64
#  5   Barrio                    9318 non-null   object
#  6   UPZ                       9318 non-null   object
#  7   Valor                     9318 non-null   object
#  8   Moneda                    9318 non-null   object
#  9   Precio                    9318 non-null   object
#  10  Precio_Millon             9318 non-null   float64
#  11  Valor_m2_Millon           9318 non-null   float64
#  12  Valor_m2_Barrio           9318 non-null   float64
# ...

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml, y = 'Precio_Millon')
plt.show()

# %%
datos_ml.query('Precio_Millon > 5000 | Precio_Millon < 60')
# Out:
#                      Tipo                                  Descripcion  \
# 207           Apartamento            Apartamento en venta en Chapinero
# 323                 Local                  Local en venta en Chapinero
# 702                  Casa                   Casa en venta en Chapinero
# 708                  Casa                   Casa en venta en Chapinero
# 829           Apartamento   Apartamento en venta en Zona Noroccidental
# 1371          Apartamento             Apartamento en venta en El Chicó
# 1414          Apartamento             Apartamento en venta en El Chicó
# 1429                Local             Local en venta en Quinta Camacho
# 1442                Local             Local en venta en Quinta Camacho
# 1518          Apartamento      Apartamento en venta en Chico Reservado
# 1532          Apartamento          Apartamento en venta en Chico Norte
# 1533          Apartamento          Apartamento en venta en Los Rosales
# ...

# %%
datos_ml = datos_ml.query('Precio_Millon < 1200 & Precio_Millon > 60')
datos_ml
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 9            Casa         Casa en venta en Zona Noroccidental             5
# 10    Apartamento  Apartamento en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
# ...

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml, y = 'Precio_Millon')
plt.show()

# %%
#Salario anual por millon
datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
datos_ml['SALARIO_ANUAL_MI']
# Out:
# 0      48.42
# 1      48.42
# 3      48.42
# 9      48.42
# 10     48.42
#         ...
# 9313   29.34
# 9314   29.34
# 9315   29.34
# 9316   29.34
# 9317   29.34
# Name: SALARIO_ANUAL_MI, Length: 8313, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=datos_ml, x='SALARIO_ANUAL_MI',y ='Valor_m2_Millon')
plt.ylim((0,15))
plt.show()

# %%
datos_ml.corr()
# Out:
#                           Habitaciones  Banos  Area  Precio_Millon  \
# Habitaciones                      1.00   0.44  0.03           0.18
# Banos                             0.44   1.00  0.04           0.66
# Area                              0.03   0.04  1.00           0.04
# Precio_Millon                     0.18   0.66  0.04           1.00
# Valor_m2_Millon                  -0.31  -0.03 -0.04           0.36
# Valor_m2_Barrio                  -0.21   0.13 -0.04           0.40
# CONJUNTO_CERRADO                 -0.12   0.16 -0.01           0.32
# INSEGURIDAD                       0.13  -0.19 -0.00          -0.37
# TERMINALES_BUS                    0.08  -0.17 -0.01          -0.28
# BARES_DISCO                       0.11  -0.12 -0.01          -0.23
# RUIDO                             0.14  -0.17 -0.00          -0.35
# OSCURO_PELIGROSO                  0.11  -0.21  0.01          -0.38
# SALARIO_MES                      -0.17   0.18 -0.01           0.42
# ...

# %%
plt.figure(figsize=(18, 8))
#https://www.tylervigen.com/spurious-correlations
#mascara = np.triu(np.ones_like(datos_ml.corr(), dtype=bool)) mask=mascara,
heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlación de las variables', fontdict={'fontsize':18}, pad=16);

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
#Para nuestro caso elegimos COD_UPZ para crear nuestra linea base
X = datos_ml[['COD_UPZ_GRUPO']]
y = datos_ml['Precio_Millon']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=99)

# %%
X_train
# Out:
#       COD_UPZ_GRUPO
# 1512         817.00
# 7864          85.00
# 6058          21.00
# 1683         817.00
# 2481          14.00
# ...             ...
# 6038          21.00
# 8875         102.00
# 2200          14.00
# 3883         803.00
# 8154          85.00
#
# [6234 rows x 1 columns]

# %%
X_test
# Out:
#       COD_UPZ_GRUPO
# 6340          74.00
# 7805          85.00
# 4902          47.00
# 7041         100.00
# 2436          14.00
# ...             ...
# 3323          14.00
# 3945         803.00
# 5572          27.00
# 3633         803.00
# 3652         803.00
#
# [2079 rows x 1 columns]

# %%
y_train
# Out:
# 1512   1050.00
# 7864    129.00
# 6058    206.38
# 1683    650.00
# 2481    250.00
#          ...
# 6038    560.00
# 8875    560.00
# 2200    685.00
# 3883    850.00
# 8154    132.00
# Name: Precio_Millon, Length: 6234, dtype: float64

# %%
#Instaciamos el modelo 
# Tomamos la variable modelo en la cual vamos a instaciar la regresion lineal de forma generica, sin parametros
modelo = LinearRegression()

# %%
#ajustamos el modelo con nuestros datos de entrenamiento
modelo.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Almacenamos predicción del modelo con datos de prueba
y_predict_test = modelo.predict(X_test)

# %%
#Validamos modelo
from sklearn.metrics import mean_absolute_error, r2_score

baseline_mae = mean_absolute_error(y_test, y_predict_test)
baseline_r2 = r2_score(y_test, y_predict_test)
print(baseline_mae,baseline_r2)
# Out:
# 187.323609443345 0.031111799984413713

# %%
X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Banos','CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA']] 

y = datos_ml["Precio_Millon"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 118.25967274431333 0.5404735562069192
# 123.22271988681676 0.5269614226488988

# %%
#Pasamos en formato dataframe un dato de prueba de un inmueble para predecir cuál seria su valor
modelo_1.predict([[816,3,2,1,50,1]])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([434.21129691])
